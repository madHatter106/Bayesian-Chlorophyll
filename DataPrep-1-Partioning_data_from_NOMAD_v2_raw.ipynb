# %%
import pickle 
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl
import seaborn as sb
from matplotlib import rcParams
from cmocean import cm
import oceansdb

# %%
pl.style.use('fivethirtyeight')
# %matplotlib inline

# %%
rcParams['axes.formatter.limits'] = (-2, 3)
rcParams['xtick.labelsize'] = 16
rcParams['ytick.labelsize'] = 16
rcParams['axes.labelsize'] = 16
rcParams['legend.fontsize'] = 16

# %%
d_ = pd.read_pickle('/accounts/ekarakoy/DATA/NOMAD/dfNomadRaw.pkl')

# %%
d_.filter(regex='a.*[0-9]+').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4459 entries, 0 to 4458
# Data columns (total 80 columns):
# ap405    4459 non-null object
# ap411    4459 non-null object
# ap443    4459 non-null object
# ap455    4459 non-null object
# ap465    4459 non-null object
# ap489    4459 non-null object
# ap510    4459 non-null object
# ap520    4459 non-null object
# ap530    4459 non-null object
# ap550    4459 non-null object
# ap555    4459 non-null object
# ap560    4459 non-null object
# ap565    4459 non-null object
# ap570    4459 non-null object
# ap590    4459 non-null object
# ap619    4459 non-null object
# ap625    4459 non-null object
# ap665    4459 non-null object
# ap670    4459 non-null object
# ap683    4459 non-null object
# ad405    4459 non-null object
# ad411    4459 non-null object
# ad443    4459 non-null object
# ad455    4459 non-null object
# ad465    4459 non-null object
# ad489    4459 non-null object
# ad510    4459 non-null object
# ad520    4459 non-null object
# ad530    4459 non-null object
# ad550    4459 non-null object
# ad555    4459 non-null object
# ad560    4459 non-null object
# ad565    4459 non-null object
# ad570    4459 non-null object
# ad590    4459 non-null object
# ad619    4459 non-null object
# ad625    4459 non-null object
# ad665    4459 non-null object
# ad670    4459 non-null object
# ad683    4459 non-null object
# ag405    4459 non-null object
# ag411    4459 non-null object
# ag443    4459 non-null object
# ag455    4459 non-null object
# ag465    4459 non-null object
# ag489    4459 non-null object
# ag510    4459 non-null object
# ag520    4459 non-null object
# ag530    4459 non-null object
# ag550    4459 non-null object
# ag555    4459 non-null object
# ag560    4459 non-null object
# ag565    4459 non-null object
# ag570    4459 non-null object
# ag590    4459 non-null object
# ag619    4459 non-null object
# ag625    4459 non-null object
# ag665    4459 non-null object
# ag670    4459 non-null object
# ag683    4459 non-null object
# a405     4459 non-null object
# a411     4459 non-null object
# a443     4459 non-null object
# a455     4459 non-null object
# a465     4459 non-null object
# a489     4459 non-null object
# a510     4459 non-null object
# a520     4459 non-null object
# a530     4459 non-null object
# a550     4459 non-null object
# a555     4459 non-null object
# a560     4459 non-null object
# a565     4459 non-null object
# a570     4459 non-null object
# a590     4459 non-null object
# a619     4459 non-null object
# a625     4459 non-null object
# a665     4459 non-null object
# a670     4459 non-null object
# a683     4459 non-null object
# dtypes: object(80)
# memory usage: 2.7+ MB

# %%
lw_cols = d_.filter(regex='lw').columns.tolist()
es_cols = d_.filter(regex='es').columns.tolist()
rrs_cols = ['rrs%s' %band[2:] for band in lw_cols]

# %%
assert len(lw_cols) == len(es_cols) == len(rrs_cols)

# %%
df_rrs = pd.DataFrame(columns=rrs_cols)
for rrs, lw, es in zip(rrs_cols, lw_cols, es_cols):
    df_rrs[rrs] = d_[lw].astype('f8') / d_[es].astype('f8')

# %%
df_rrs[df_rrs<0] = np.NaN
df_rrs[df_rrs==1] = np.NaN
df_rrs.insert(0, 'id', d_.id)

# %%
df_rrs.min().value_counts()
# Out:
# 0.000000     5
# 0.000051     1
# 0.000079     1
# 0.000896     1
# 0.000183     1
# 0.000600     1
# 0.001216     1
# 0.000251     1
# 0.001000     1
# 0.000229     1
# 0.000284     1
# 0.000533     1
# 0.000800     1
# 0.000261     1
# 0.000190     1
# 0.000379     1
# 10.000000    1
# dtype: int64

# %%
df_rrs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4459 entries, 0 to 4458
# Data columns (total 21 columns):
# id        4459 non-null object
# rrs405    12 non-null float64
# rrs411    4293 non-null float64
# rrs443    4456 non-null float64
# rrs455    393 non-null float64
# rrs465    375 non-null float64
# rrs489    4422 non-null float64
# rrs510    3435 non-null float64
# rrs520    1559 non-null float64
# rrs530    1589 non-null float64
# rrs550    912 non-null float64
# rrs555    3255 non-null float64
# rrs560    1193 non-null float64
# rrs565    1884 non-null float64
# rrs570    816 non-null float64
# rrs590    690 non-null float64
# rrs619    883 non-null float64
# rrs625    1884 non-null float64
# rrs665    2641 non-null float64
# rrs670    1598 non-null float64
# rrs683    2008 non-null float64
# dtypes: float64(20), object(1)
# memory usage: 731.6+ KB

# %%
df_rrs.tail().T
# Out:
#                4454         4455         4456         4457         4458
# id             6901         6902         6914         6903         6915
# rrs405          NaN          NaN          NaN          NaN          NaN
# rrs411   0.00109978   0.00179985   0.00270028   0.00070068  0.000699996
# rrs443   0.00139999   0.00189976   0.00299982  0.000800468   0.00090064
# rrs455          NaN          NaN          NaN          NaN          NaN
# rrs465          NaN          NaN          NaN          NaN          NaN
# rrs489   0.00220024    0.0023003    0.0037003   0.00110013   0.00140013
# rrs510   0.00240025   0.00229985   0.00329987   0.00119948   0.00159922
# rrs520   0.00260035   0.00240002   0.00309999    0.0012998   0.00179921
# rrs530   0.00290029   0.00260018   0.00310025   0.00140037   0.00210058
# rrs550   0.00309985   0.00260031   0.00269969   0.00150043   0.00240068
# rrs555   0.00310032   0.00259972    0.0025997   0.00149993   0.00239964
# rrs560   0.00320009   0.00250019   0.00250011   0.00150042    0.0024992
# rrs565   0.00319961   0.00250004   0.00240023   0.00150033   0.00249932
# rrs570   0.00310017   0.00229967   0.00230034   0.00139972   0.00239944
# rrs590          NaN          NaN          NaN          NaN          NaN
# rrs619  0.000900104  0.000499737   0.00049973  0.000399584  0.000499204
# rrs625  0.000899624  0.000499665  0.000500382  0.000399905  0.000500436
# rrs665  0.000699561  0.000399926  0.000399674  0.000400347  0.000499824
# rrs670  0.000699834  0.000500089   0.00039986   0.00049946  0.000699562
# rrs683  0.000800236  0.000600008  0.000400418  0.000700213   0.00100086

# %%
df_absorption = d_.filter(regex='a.*[0-9]+').astype('f8')
df_absorption[df_absorption<0] = np.NaN
df_absorption.insert(0, 'id', d_.id)
df_absorption.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4459 entries, 0 to 4458
# Data columns (total 81 columns):
# id       4459 non-null object
# ap405    1269 non-null float64
# ap411    1272 non-null float64
# ap443    1279 non-null float64
# ap455    1279 non-null float64
# ap465    1279 non-null float64
# ap489    1278 non-null float64
# ap510    1278 non-null float64
# ap520    1277 non-null float64
# ap530    1277 non-null float64
# ap550    1267 non-null float64
# ap555    1262 non-null float64
# ap560    1253 non-null float64
# ap565    1245 non-null float64
# ap570    1241 non-null float64
# ap590    1250 non-null float64
# ap619    1259 non-null float64
# ap625    1258 non-null float64
# ap665    1270 non-null float64
# ap670    1270 non-null float64
# ap683    1268 non-null float64
# ad405    1228 non-null float64
# ad411    1231 non-null float64
# ad443    1238 non-null float64
# ad455    1238 non-null float64
# ad465    1238 non-null float64
# ad489    1237 non-null float64
# ad510    1237 non-null float64
# ad520    1236 non-null float64
# ad530    1236 non-null float64
# ad550    1226 non-null float64
# ad555    1221 non-null float64
# ad560    1212 non-null float64
# ad565    1204 non-null float64
# ad570    1200 non-null float64
# ad590    1209 non-null float64
# ad619    1219 non-null float64
# ad625    1217 non-null float64
# ad665    1229 non-null float64
# ad670    1228 non-null float64
# ad683    1224 non-null float64
# ag405    1182 non-null float64
# ag411    1182 non-null float64
# ag443    1182 non-null float64
# ag455    1182 non-null float64
# ag465    1182 non-null float64
# ag489    1182 non-null float64
# ag510    1181 non-null float64
# ag520    1181 non-null float64
# ag530    1181 non-null float64
# ag550    1181 non-null float64
# ag555    1181 non-null float64
# ag560    1181 non-null float64
# ag565    1181 non-null float64
# ag570    1181 non-null float64
# ag590    1181 non-null float64
# ag619    1179 non-null float64
# ag625    1178 non-null float64
# ag665    1138 non-null float64
# ag670    1137 non-null float64
# ag683    1131 non-null float64
# a405     1128 non-null float64
# a411     1131 non-null float64
# a443     1138 non-null float64
# a455     1138 non-null float64
# a465     1138 non-null float64
# a489     1137 non-null float64
# a510     1136 non-null float64
# a520     1135 non-null float64
# a530     1135 non-null float64
# a550     1127 non-null float64
# a555     1122 non-null float64
# a560     1113 non-null float64
# a565     1106 non-null float64
# a570     1102 non-null float64
# a590     1111 non-null float64
# a619     1115 non-null float64
# a625     1113 non-null float64
# a665     1087 non-null float64
# a670     1086 non-null float64
# a683     1078 non-null float64
# dtypes: float64(80), object(1)
# memory usage: 2.8+ MB

# %%
df_backscatter = d_.filter(regex='b.*[0-9]+').astype('f8')
df_backscatter[df_backscatter<0] = np.NaN
df_backscatter.insert(0, 'id', d_.id)
df_backscatter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4459 entries, 0 to 4458
# Data columns (total 35 columns):
# id        4459 non-null object
# bb405     369 non-null float64
# bb411     369 non-null float64
# bb443     369 non-null float64
# bb455     369 non-null float64
# bb465     369 non-null float64
# bb489     369 non-null float64
# bb510     369 non-null float64
# bb520     369 non-null float64
# bb530     381 non-null float64
# bb550     369 non-null float64
# bb555     369 non-null float64
# bb560     369 non-null float64
# bb565     369 non-null float64
# bb570     369 non-null float64
# bb590     369 non-null float64
# bb619     369 non-null float64
# bb625     369 non-null float64
# bb665     369 non-null float64
# bb670     369 non-null float64
# bb683     369 non-null float64
# bbr420    33 non-null float64
# bbr442    247 non-null float64
# bbr470    314 non-null float64
# bbr488    55 non-null float64
# bbr510    139 non-null float64
# bbr514    70 non-null float64
# bbr532    107 non-null float64
# bbr550    33 non-null float64
# bbr555    13 non-null float64
# bbr589    247 non-null float64
# bbr620    132 non-null float64
# bbr671    247 non-null float64
# bbr676    122 non-null float64
# bbr870    0 non-null float64
# dtypes: float64(34), object(1)
# memory usage: 1.2+ MB

# %%
def fill_chl(row):
    if np.isnan(row.hplc_chl):
        return row.fluo_chl
    else:
        return row.hplc_chl

# %%
rrs_cols = [col for col in df_rrs.columns if 'rrs' in col]
aop_cols_x = ['id', 'datetime']
aop_cols_x_floats = ['lat', 'lon', 'etopo2', 'oisst',
                   'wtemp', 'sal']
aop_cols_y_floats = ['fluo_chl', 'hplc_chl']
d_cols_x = ['id', 'Datetime']
d_cols_x_floats = ['lat' ,'lon', 'etopo2', 'oisst', 'wt', 'sal']
d_cols_y_floats = ['chl', 'chl_a']
d_aop = pd.DataFrame(columns=aop_cols_x + aop_cols_x_floats +
                     rrs_cols + aop_cols_y_floats)
d_aop[aop_cols_x] = d_[d_cols_x]
d_aop[aop_cols_x_floats] = d_[d_cols_x_floats].astype('f8')
d_aop[rrs_cols] = df_rrs[rrs_cols]
d_aop[aop_cols_y_floats] = d_[d_cols_y_floats].astype('f8')

# %%
d_aop['chl'] = d_aop.apply(fill_chl, axis=1)

# %%
d_aop[d_aop==-999] = np.NaN

# %%
d_aop.insert(d_aop.shape[1]-3, 'is_hplc', ~d_aop.hplc_chl.isnull())

# %%
d_aop.describe().T
# Out:
#            count         mean          std         min        25%         50%  \
# lat       4459.0     1.868658    44.765125  -77.035600 -61.299000   27.093000
# lon       4459.0   -61.592062    53.894958 -179.955000 -82.699950  -67.675000
# etopo2    4459.0  1312.346715  1766.435289    0.000000  18.000000  240.000000
# oisst     4459.0    14.841534    10.374969   -1.800000   1.860000   16.380000
# wtemp     1235.0    18.021513     8.203662   -1.880000  13.425000   18.090000
# sal        672.0    28.717463     8.397708    0.080000  24.885000   33.250000
# rrs405      12.0     0.006333     0.003972    0.001216   0.001838    0.006932
# rrs411    4293.0     0.004881     0.003447    0.000051   0.002509    0.003984
# rrs443    4456.0     0.004652     0.003002    0.000190   0.002617    0.003899
# rrs455     393.0     0.003223     0.002901    0.000229   0.001604    0.002523
# rrs465     375.0     0.004766     0.002458    0.000896   0.002925    0.004335
# rrs489    4422.0     0.004590     0.002768    0.000284   0.003051    0.004153
# rrs510    3435.0     0.004130     0.003130    0.000261   0.002831    0.003425
# rrs520    1559.0     0.004302     0.003926    0.000533   0.002356    0.002900
# rrs530    1589.0     0.004973     0.004962    0.000251   0.002300    0.003171
# rrs550     912.0     0.006632     0.006480    0.001000   0.002298    0.004822
# rrs555    3255.0     0.003256     0.003536    0.000183   0.001588    0.002071
# rrs560    1193.0     0.005835     0.006150    0.000800   0.001800    0.003900
# rrs565    1884.0     0.003620     0.004486    0.000379   0.001356    0.001874
# rrs570     816.0     0.005526     0.006038    0.000600   0.001448    0.002600
# rrs590     690.0     0.003565     0.005225    0.000079   0.000747    0.001459
# rrs619     883.0     0.002230     0.003681    0.000000   0.000200    0.000500
# rrs625    1884.0     0.001901     0.003190    0.000000   0.000228    0.000486
# rrs665    2641.0     0.000689     0.001687    0.000000   0.000088    0.000173
# rrs670    1598.0     0.001557     0.002387    0.000000   0.000200    0.000614
# rrs683    2008.0     0.001312     0.002300    0.000000   0.000100    0.000328
# fluo_chl  3392.0     2.703251     5.611762    0.012000   0.274000    0.830000
# hplc_chl  1381.0     2.285293     5.752391    0.017000   0.145000    0.538000
# chl       1381.0     2.285293     5.752391    0.017000   0.145000    0.538000
#
#                   75%          max
# lat         34.458500    79.690000
# lon        -63.961500   179.907000
# etopo2    2789.500000  7978.000000
# oisst       24.430000    30.890000
# wtemp       24.441000    36.250000
# sal         33.630000    37.010000
# rrs405       0.009987     0.011736
# rrs411       0.006301     0.030600
# rrs443       0.006076     0.036769
# rrs455       0.003985     0.040897
# rrs465       0.006119     0.015112
# rrs489       0.005655     0.063814
# rrs510       0.004242     0.077740
# rrs520       0.004400     0.034800
# rrs530       0.006051     0.098617
# rrs550       0.009000     0.108867
# rrs555       0.003141     0.046600
# rrs560       0.007900     0.109818
# rrs565       0.003456     0.049500
# rrs570       0.008025     0.050400
# rrs590       0.005375     0.097025
# rrs619       0.002900     0.039300
# rrs625       0.002479     0.043714
# rrs665       0.000428     0.028000
# rrs670       0.002000     0.027700
# rrs683       0.001700     0.033300
# fluo_chl     2.240080    77.864800
# hplc_chl     1.694000    70.213300
# chl          1.694000    70.213300

# %%
d_aop.tail().T
# Out:
#                          4454                 4455                 4456  \
# id                       6901                 6902                 6914
# datetime  2006-10-05 15:40:00  2006-10-05 17:00:00  2006-10-05 18:10:00
# lat                   26.3795              26.3167              26.2545
# lon                  -82.2707             -82.4491             -82.6158
# etopo2                     26                   22                   24
# oisst                   28.91                28.91                28.91
# wtemp                     NaN                  NaN                  NaN
# sal                       NaN                  NaN                  NaN
# rrs405                    NaN                  NaN                  NaN
# rrs411             0.00109978           0.00179985           0.00270028
# rrs443             0.00139999           0.00189976           0.00299982
# rrs455                    NaN                  NaN                  NaN
# rrs465                    NaN                  NaN                  NaN
# rrs489             0.00220024            0.0023003            0.0037003
# rrs510             0.00240025           0.00229985           0.00329987
# rrs520             0.00260035           0.00240002           0.00309999
# rrs530             0.00290029           0.00260018           0.00310025
# rrs550             0.00309985           0.00260031           0.00269969
# rrs555             0.00310032           0.00259972            0.0025997
# rrs560             0.00320009           0.00250019           0.00250011
# rrs565             0.00319961           0.00250004           0.00240023
# rrs570             0.00310017           0.00229967           0.00230034
# rrs590                    NaN                  NaN                  NaN
# rrs619            0.000900104          0.000499737           0.00049973
# rrs625            0.000899624          0.000499665          0.000500382
# rrs665            0.000699561          0.000399926          0.000399674
# rrs670            0.000699834          0.000500089           0.00039986
# rrs683            0.000800236          0.000600008          0.000400418
# is_hplc                 False                False                False
# fluo_chl              4.62784              2.95997              0.95114
# hplc_chl                  NaN                  NaN                  NaN
# chl                       NaN                  NaN                  NaN
#
#                          4457                 4458
# id                       6903                 6915
# datetime  2006-10-05 20:30:00  2006-10-05 21:22:00
# lat                   26.5184              26.5567
# lon                  -82.5594             -82.4766
# etopo2                     24                   18
# oisst                   28.91                28.91
# wtemp                     NaN                  NaN
# sal                       NaN                  NaN
# rrs405                    NaN                  NaN
# rrs411             0.00070068          0.000699996
# rrs443            0.000800468           0.00090064
# rrs455                    NaN                  NaN
# rrs465                    NaN                  NaN
# rrs489             0.00110013           0.00140013
# rrs510             0.00119948           0.00159922
# rrs520              0.0012998           0.00179921
# rrs530             0.00140037           0.00210058
# rrs550             0.00150043           0.00240068
# rrs555             0.00149993           0.00239964
# rrs560             0.00150042            0.0024992
# rrs565             0.00150033           0.00249932
# rrs570             0.00139972           0.00239944
# rrs590                    NaN                  NaN
# rrs619            0.000399584          0.000499204
# rrs625            0.000399905          0.000500436
# rrs665            0.000400347          0.000499824
# rrs670             0.00049946          0.000699562
# rrs683            0.000700213           0.00100086
# is_hplc                 False                False
# fluo_chl              4.54228              5.80693
# hplc_chl                  NaN                  NaN
# chl                       NaN                  NaN

# %%
d_aop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4459 entries, 0 to 4458
# Data columns (total 32 columns):
# id          4459 non-null object
# datetime    4459 non-null datetime64[ns]
# lat         4459 non-null float64
# lon         4459 non-null float64
# etopo2      4459 non-null float64
# oisst       4459 non-null float64
# wtemp       1235 non-null float64
# sal         672 non-null float64
# rrs405      12 non-null float64
# rrs411      4293 non-null float64
# rrs443      4456 non-null float64
# rrs455      393 non-null float64
# rrs465      375 non-null float64
# rrs489      4422 non-null float64
# rrs510      3435 non-null float64
# rrs520      1559 non-null float64
# rrs530      1589 non-null float64
# rrs550      912 non-null float64
# rrs555      3255 non-null float64
# rrs560      1193 non-null float64
# rrs565      1884 non-null float64
# rrs570      816 non-null float64
# rrs590      690 non-null float64
# rrs619      883 non-null float64
# rrs625      1884 non-null float64
# rrs665      2641 non-null float64
# rrs670      1598 non-null float64
# rrs683      2008 non-null float64
# is_hplc     4459 non-null bool
# fluo_chl    3392 non-null float64
# hplc_chl    1381 non-null float64
# chl         1381 non-null float64
# dtypes: bool(1), datetime64[ns](1), float64(29), object(1)
# memory usage: 1.1+ MB

# %%
corr_columns = ['lat', 'lon', 'etopo2', 'oisst', 'wtemp', 'sal'] +\
               [col for col in d_aop.columns.tolist() if 'rrs' in col] +\
               ['fluo_chl', 'hplc_chl', 'chl']
f, ax = pl.subplots(figsize=(15,15))
sb.heatmap(d_aop[corr_columns].corr(), ax=ax, annot=True,
           mask=np.triu(np.ones([len(corr_columns)]*2), k=1),
           cmap=cm.balance_r, vmin=-1, vmax=1);

# %% [markdown]
# Taking a look at what the data would look like as is for an OC4 evaluation

# %%
df_oc4 = pd.DataFrame(columns=['id', 'maxBlue', 'mxBlId', 'mxBl2Gr', 'mxBl2Gr_log',
                              'chl', 'chl_log'])
df_oc4['maxBlue'] = d_aop.loc[:, ['rrs443','rrs489','rrs510']].max(axis=1)
df_oc4['mxBl2Gr'] = df_oc4.maxBlue / d_aop.rrs555
df_oc4['id'] = d_aop.id
df_oc4['mxBlId'] = d_aop.loc[:, ['rrs443', 'rrs489', 'rrs510']].idxmax(axis=1)
df_oc4['mxBl2Gr_log'] = np.log10(df_oc4.mxBl2Gr)
df_oc4['chl'] = d_aop.chl
df_oc4['chl_log'] = np.log10(df_oc4.chl)

# %%
sb.pairplot(df_oc4[['mxBlId', 'mxBl2Gr_log', 'chl_log']].dropna(),
            size=7, hue='mxBlId')

# %%
sb.heatmap(df_oc4.drop(['id', 'mxBlId'], axis=1).corr(),
           annot=True, cmap=cm.balance_r,
           mask=np.triu(np.ones([df_oc4.shape[1]-2]*2)),
           vmin=-1, vmax=1);

# %%
d_aop.to_pickle('./pickleJar/dfNomad_AOP.pkl')

# %%
d_aop.insert(2, 'doy', d_aop.datetime.dt.dayofyear +
             d_aop.datetime.dt.hour/24 + d_aop.datetime.dt.minute/60)

# %%
d_aop.head().T
# Out:
#                             0                    1                    2  \
# id                       1565                 1566                 1567
# datetime  2003-04-15 15:15:00  2003-04-15 16:50:00  2003-04-15 17:50:00
# doy                   105.875                106.5              106.542
# lat                   38.4279               38.368              38.3074
# lon                    -76.61                -76.5               -76.44
# etopo2                      0                    0                    1
# oisst                     3.7                  3.7                  3.7
# wtemp                     NaN                  NaN                  NaN
# sal                       NaN                  NaN                  NaN
# rrs405                    NaN                  NaN                  NaN
# rrs411              0.0012044           0.00106171          0.000971132
# rrs443             0.00168608           0.00138402           0.00118548
# rrs455             0.00218376           0.00167854            0.0013255
# rrs465                    NaN                  NaN                  NaN
# rrs489             0.00329309           0.00217292            0.0018432
# rrs510             0.00403634           0.00249924           0.00228772
# rrs520                    NaN                  NaN                  NaN
# rrs530             0.00577855            0.0033578           0.00341202
# rrs550                    NaN                  NaN                  NaN
# rrs555             0.00747919           0.00415208           0.00424561
# rrs560                    NaN                  NaN                  NaN
# rrs565             0.00880889           0.00500216           0.00491265
# rrs570                    NaN                  NaN                  NaN
# rrs590             0.00858373           0.00469617           0.00446443
# rrs619                    NaN                  NaN                  NaN
# rrs625             0.00661863            0.0032279           0.00300022
# rrs665                    NaN                  NaN                  NaN
# rrs670             0.00346456           0.00169488           0.00161228
# rrs683             0.00366944           0.00217309            0.0017266
# is_hplc                 False                False                False
# fluo_chl                38.19                35.01                26.91
# hplc_chl                  NaN                  NaN                  NaN
# chl                       NaN                  NaN                  NaN
#
#                             3                    4
# id                       1568                 1559
# datetime  2003-04-17 18:15:00  2003-07-21 18:27:00
# doy                       108                203.2
# lat                   38.6367              38.3047
# lon                    -76.32               -76.44
# etopo2                      3                    1
# oisst                     3.7                22.03
# wtemp                     NaN                  NaN
# sal                       NaN                  NaN
# rrs405                    NaN                  NaN
# rrs411              0.0014718          0.000905091
# rrs443             0.00174123           0.00102233
# rrs455             0.00214686           0.00121305
# rrs465                    NaN                  NaN
# rrs489             0.00287731           0.00150593
# rrs510             0.00366425           0.00190341
# rrs520                    NaN                  NaN
# rrs530             0.00489781           0.00244952
# rrs550                    NaN                  NaN
# rrs555              0.0069817           0.00280069
# rrs560                    NaN                  NaN
# rrs565             0.00818023           0.00305456
# rrs570                    NaN                  NaN
# rrs590             0.00785243           0.00264051
# rrs619                    NaN                  NaN
# rrs625             0.00576696           0.00218222
# rrs665                    NaN                  NaN
# rrs670             0.00323384           0.00179052
# rrs683             0.00411814            0.0023083
# is_hplc                 False                False
# fluo_chl                47.96                23.55
# hplc_chl                  NaN                  NaN
# chl                       NaN                  NaN

# %% [markdown]
# ### Adding temperature & salinity climatology from the world ocean atlas, including mean, and standard error for data modeling (better using the mean).
#
# I'll also add bathymetry to compare with the available data

# %%
db_woa = oceansdb.WOA()

# %%
db_etopo = oceansdb.ETOPO()

# %%
def get_woa(row, var_='sea_water_salinity', stat_='mean'):
    val = db_woa[var_].extract(var=stat_, doy=row.doy, depth=0,
                               lat=row.lat, lon=row.lon
                              )[stat_]
    if val.mask:
        return np.NaN
    else:
        return val[0]
    
    
def get_etopo(row):
    val = db_etopo['topography'].extract(lat=row.lat, lon=row.lon)['height']
    if type(val) is np.ma.masked_array:
        if val.mask:
            return np.NaN
        else:
            return val.data[0]
    else:
        return val[0]

# %%
d_temp = pd.DataFrame(columns=['doy', 'lat', 'lon', 'bathymetry',
                               'woa_sal_mn', 'woa_sal_se', 'woa_sst_mn', 'woa_sst_se'])

# %%
d_temp[['doy', 'lat', 'lon']] = d_aop[['doy', 'lat', 'lon']]

# %%
var_  = 'sea_water_salinity'
for stat_ in ['s_mn', 's_se']:
    d_temp[f'woa_sal_{stat_[2:]}'] = d_temp.apply(get_woa, axis=1, args=(var_, stat_))

# %%
var_  = 'sea_water_temperature'
for stat_ in ['t_mn', 't_se']:
    d_temp[f'woa_sst_{stat_[2:]}'] = d_temp.apply(get_woa, axis=1, args=(var_, stat_))

# %%
d_temp['bathymetry'] = d_temp.apply(get_etopo, axis=1)

# %%
d_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4459 entries, 0 to 4458
# Data columns (total 8 columns):
# doy           4459 non-null float64
# lat           4459 non-null float64
# lon           4459 non-null float64
# bathymetry    4459 non-null float64
# woa_sal_mn    2511 non-null float64
# woa_sal_se    2511 non-null float64
# woa_sst_mn    2516 non-null float64
# woa_sst_se    2516 non-null float64
# dtypes: float64(8)
# memory usage: 278.8 KB

# %%
d_aop.insert(6, 'bathymetry', d_temp.bathymetry)

# %%
d_aop.insert(9, 'woa_sst_mean', d_temp.woa_sst_mn)
d_aop.insert(10, 'woa_sst_se', d_temp.woa_sst_se)

# %%
d_aop.insert(12, 'woa_sal_mean', d_temp.woa_sal_mn)
d_aop.insert(13, 'woa_sal_se', d_temp.woa_sal_se)
d_aop.head().T
# Out:
#                                 0                    1                    2  \
# id                           1565                 1566                 1567
# datetime      2003-04-15 15:15:00  2003-04-15 16:50:00  2003-04-15 17:50:00
# doy                       105.875                106.5              106.542
# lat                       38.4279               38.368              38.3074
# lon                        -76.61                -76.5               -76.44
# etopo2                          0                    0                    1
# bathymetry                 -3.044               -10.44               -8.956
# oisst                         3.7                  3.7                  3.7
# wtemp                         NaN                  NaN                  NaN
# woa_sst_mean                  NaN                  NaN                  NaN
# woa_sst_se                    NaN                  NaN                  NaN
# sal                           NaN                  NaN                  NaN
# woa_sal_mean                  NaN                  NaN                  NaN
# woa_sal_se                    NaN                  NaN                  NaN
# rrs405                        NaN                  NaN                  NaN
# rrs411                  0.0012044           0.00106171          0.000971132
# rrs443                 0.00168608           0.00138402           0.00118548
# rrs455                 0.00218376           0.00167854            0.0013255
# rrs465                        NaN                  NaN                  NaN
# rrs489                 0.00329309           0.00217292            0.0018432
# rrs510                 0.00403634           0.00249924           0.00228772
# rrs520                        NaN                  NaN                  NaN
# rrs530                 0.00577855            0.0033578           0.00341202
# rrs550                        NaN                  NaN                  NaN
# rrs555                 0.00747919           0.00415208           0.00424561
# rrs560                        NaN                  NaN                  NaN
# rrs565                 0.00880889           0.00500216           0.00491265
# rrs570                        NaN                  NaN                  NaN
# rrs590                 0.00858373           0.00469617           0.00446443
# rrs619                        NaN                  NaN                  NaN
# rrs625                 0.00661863            0.0032279           0.00300022
# rrs665                        NaN                  NaN                  NaN
# rrs670                 0.00346456           0.00169488           0.00161228
# rrs683                 0.00366944           0.00217309            0.0017266
# is_hplc                     False                False                False
# fluo_chl                    38.19                35.01                26.91
# hplc_chl                      NaN                  NaN                  NaN
# chl                           NaN                  NaN                  NaN
#
#                                 3                    4
# id                           1568                 1559
# datetime      2003-04-17 18:15:00  2003-07-21 18:27:00
# doy                           108                203.2
# lat                       38.6367              38.3047
# lon                        -76.32               -76.44
# etopo2                          3                    1
# bathymetry                -10.008               -9.118
# oisst                         3.7                22.03
# wtemp                         NaN                  NaN
# woa_sst_mean                  NaN                  NaN
# woa_sst_se                    NaN                  NaN
# sal                           NaN                  NaN
# woa_sal_mean                  NaN                  NaN
# woa_sal_se                    NaN                  NaN
# rrs405                        NaN                  NaN
# rrs411                  0.0014718          0.000905091
# rrs443                 0.00174123           0.00102233
# rrs455                 0.00214686           0.00121305
# rrs465                        NaN                  NaN
# rrs489                 0.00287731           0.00150593
# rrs510                 0.00366425           0.00190341
# rrs520                        NaN                  NaN
# rrs530                 0.00489781           0.00244952
# rrs550                        NaN                  NaN
# rrs555                  0.0069817           0.00280069
# rrs560                        NaN                  NaN
# rrs565                 0.00818023           0.00305456
# rrs570                        NaN                  NaN
# rrs590                 0.00785243           0.00264051
# rrs619                        NaN                  NaN
# rrs625                 0.00576696           0.00218222
# rrs665                        NaN                  NaN
# rrs670                 0.00323384           0.00179052
# rrs683                 0.00411814            0.0023083
# is_hplc                     False                False
# fluo_chl                    47.96                23.55
# hplc_chl                      NaN                  NaN
# chl                           NaN                  NaN

# %%
d_aop.to_pickle('./pickleJar/dfNomad_AOP.pkl')

# %% [markdown]
# ### Partition the rest of the data in coherent dataframes for future use

# %%
cols_all = d_.columns.tolist()
cols_aop = d_aop.columns.tolist()
cols_bb = df_backscatter.columns.tolist()
cols_a = df_absorption.columns.tolist()

# %%
other_cols = [col for col in cols_all
              if 'lw' in col or 'es' in col or 'kd' in col or 'z_' in col]

# %%
pigment_cols = list(set(cols_all) -
                    set(cols_aop + cols_bb + cols_a + ['Datetime', 'cruise', 'wt']
                        + other_cols)
                   )

pigment_cols.insert(0, 'id')

# %%
other_cols.insert(0, 'id')

# %%
df_pigments = d_[pigment_cols]
df_misc = d_[other_cols]

# %%
with open('./pickleJar/NOMAD_AOP&IOPs.pkl', 'wb') as f:
    datadict = dict(d_aop=d_aop, d_bb=df_backscatter,
                   d_absorp=df_absorption, d_pigments=df_pigments,
                    d_misc=df_misc)
    pickle.dump(datadict, f)

# %% [markdown]
# # TODO: clean up pickleJar directory

# %%
import pandas as pd
import pathlib
from xml.dom.minidom import *

# %%
provinces = {}
home = pathlib.Path.home()
fp = home / 'DEV/Longhurst-Province-Finder/longhurst.xml'
tree = parse(fp)

# %%
for node in tree.getElementsByTagName('MarineRegions:longhurst'):

	# 1. Get province code, name and bounding box from file
	provCode = node.getElementsByTagName('MarineRegions:provcode')[0].firstChild.data
	provName = node.getElementsByTagName('MarineRegions:provdescr')[0].firstChild.data
	fid = node.getAttribute("fid")
	b = node.getElementsByTagName('gml:coordinates')[0].firstChild.data

	# 2. Parse bounding box coordinates
	b = b.split(' ')
	x1,y1 = b[0].split(',')
	x2,y2 = b[1].split(',')
	x1 = float(x1)
	y1 = float(y1)
	x2 = float(x2)
	y2 = float(y2)

	provinces[fid] = {'provName': provName, 'provCode': provCode, 'x1': x1, 'y1': y1, 'x2': x2, 'y2': y2}

# %%
d = pd.DataFrame(provinces).T

# %%
d.head()
# Out:
#              provCode                                     provName       x1  \
# longhurst.1      FKLD       Coastal - SW Atlantic Shelves Province    -70.5
# longhurst.10     BENG  Coastal - Benguela Current Coastal Province      7.5
# longhurst.11     ARCH   Trades - Archipelagic Deep Basins Province     92.5
# longhurst.12     SUND     Coastal - Sunda-Arafura Shelves Province  98.1819
# longhurst.13     GUIN    Coastal - Guinea Current Coastal Province    -17.5
#
#                    x2       y1       y2
# longhurst.1     -51.5    -55.5    -38.5
# longhurst.10  18.3499    -35.5    -16.5
# longhurst.11    174.5    -33.5     22.5
# longhurst.12  147.147 -17.7192  21.9356
# longhurst.13  13.8536    -17.5  11.6837

# %%
d.tail()
# Out:
#              provCode                                        provName  \
# longhurst.54     BPLR            Polar - Boreal Polar Province (POLR)
# longhurst.6      EAFR            Coastal - E. Africa Coastal Province
# longhurst.7      AUSW  Coastal - Australia-Indonesia Coastal Province
# longhurst.8      AUSE      Coastal - East Australian Coastal Province
# longhurst.9      ISSG    Trades - Indian S. Subtropical Gyre Province
#
#                    x1      x2      y1       y2
# longhurst.54 -179.999  179.99  50.735  89.8992
# longhurst.6      15.5    52.5   -39.5     -6.5
# longhurst.7      94.5   146.5   -39.5      7.5
# longhurst.8     144.5   156.5   -39.5    -13.5
# longhurst.9      30.5   117.5   -37.5    -10.5

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 54 entries, longhurst.1 to longhurst.9
# Data columns (total 6 columns):
# provCode    54 non-null object
# provName    54 non-null object
# x1          54 non-null object
# x2          54 non-null object
# y1          54 non-null object
# y2          54 non-null object
# dtypes: object(6)
# memory usage: 3.0+ KB

# %%
d.rename(columns={'x1': 'lon_min', 'x2': 'lon_max', 'y1': 'lat_min', 'y2': 'lat_max'}, inplace=True)

# %%
d.set_index('provCode').head()
# Out:
#                                              provName  lon_min  lon_max  \
# provCode
# FKLD           Coastal - SW Atlantic Shelves Province    -70.5    -51.5
# BENG      Coastal - Benguela Current Coastal Province      7.5  18.3499
# ARCH       Trades - Archipelagic Deep Basins Province     92.5    174.5
# SUND         Coastal - Sunda-Arafura Shelves Province  98.1819  147.147
# GUIN        Coastal - Guinea Current Coastal Province    -17.5  13.8536
#
#           lat_min  lat_max
# provCode
# FKLD        -55.5    -38.5
# BENG        -35.5    -16.5
# ARCH        -33.5     22.5
# SUND     -17.7192  21.9356
# GUIN        -17.5  11.6837

# %%
d['provType'] = d.provName.apply(lambda x: x.split(' - ')[0])

# %%
d.reset_index(inplace=True)

# %%
d.rename(columns={'index': 'provID'}, inplace=True)

# %%
d.head()
# Out:
#              provID provCode    provType  provCat  \
# provNo
# 1       longhurst.1     FKLD     Coastal        0
# 2       longhurst.2     CHIL     Coastal        0
# 3       longhurst.3     TASM  Westerlies        3
# 4       longhurst.4     BRAZ     Coastal        0
# 5       longhurst.5     SATL      Trades        2
#
#                                              provName  lon_min  lon_max  \
# provNo
# 1              Coastal - SW Atlantic Shelves Province    -70.5    -51.5
# 2       Coastal - Chile-Peru Current Coastal Province    -86.5    -69.5
# 3                    Westerlies - Tasman Sea Province    146.5  174.975
# 4           Coastal - Brazil Current Coastal Province -58.5497    -33.5
# 5       Trades - South Atlantic Gyral Province (SATG)    -53.5     15.5
#
#        lat_min lat_max
# provNo
# 1        -55.5   -38.5
# 2        -55.5     0.5
# 3        -43.5   -33.5
# 4        -41.5   -10.5
# 5        -41.5    -2.5

# %%
d['provNo'] = [no.split('.')[1] for no in d.provNum.tolist()]

# %%
d.head()
# Out:
#         provNum provCode                                     provName  \
# 0   longhurst.1     FKLD       Coastal - SW Atlantic Shelves Province
# 1  longhurst.10     BENG  Coastal - Benguela Current Coastal Province
# 2  longhurst.11     ARCH   Trades - Archipelagic Deep Basins Province
# 3  longhurst.12     SUND     Coastal - Sunda-Arafura Shelves Province
# 4  longhurst.13     GUIN    Coastal - Guinea Current Coastal Province
#
#    lon_min  lon_max  lat_min  lat_max provType provNo
# 0    -70.5    -51.5    -55.5    -38.5  Coastal      1
# 1      7.5  18.3499    -35.5    -16.5  Coastal     10
# 2     92.5    174.5    -33.5     22.5   Trades     11
# 3  98.1819  147.147 -17.7192  21.9356  Coastal     12
# 4    -17.5  13.8536    -17.5  11.6837  Coastal     13

# %%
d.set_index('provNo', inplace=True)

# %%
d.index.name = 'provNum'

# %%
d.index = d.index.astype('int')

# %%
d.sort_index(inplace=True)

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54 entries, 1 to 54
# Data columns (total 9 columns):
# provID      54 non-null object
# provCode    54 non-null object
# provType    54 non-null object
# provCat     54 non-null int8
# provName    54 non-null object
# lon_min     54 non-null object
# lon_max     54 non-null object
# lat_min     54 non-null object
# lat_max     54 non-null object
# dtypes: int8(1), object(8)
# memory usage: 6.3+ KB

# %%
d.head()
# Out:
#               provID provCode    provType  provCat  \
# provNum
# 1        longhurst.1     FKLD     Coastal        0
# 2        longhurst.2     CHIL     Coastal        0
# 3        longhurst.3     TASM  Westerlies        3
# 4        longhurst.4     BRAZ     Coastal        0
# 5        longhurst.5     SATL      Trades        2
#
#                                               provName  lon_min  lon_max  \
# provNum
# 1               Coastal - SW Atlantic Shelves Province    -70.5    -51.5
# 2        Coastal - Chile-Peru Current Coastal Province    -86.5    -69.5
# 3                     Westerlies - Tasman Sea Province    146.5  174.975
# 4            Coastal - Brazil Current Coastal Province -58.5497    -33.5
# 5        Trades - South Atlantic Gyral Province (SATG)    -53.5     15.5
#
#         lat_min lat_max
# provNum
# 1         -55.5   -38.5
# 2         -55.5     0.5
# 3         -43.5   -33.5
# 4         -41.5   -10.5
# 5         -41.5    -2.5

# %%
d['provCat'] = d.provType.astype('category').cat.codes

# %%
d.head()
# Out:
#             provNum provCode                                       provName  \
# provNo
# 1       longhurst.1     FKLD         Coastal - SW Atlantic Shelves Province
# 2       longhurst.2     CHIL  Coastal - Chile-Peru Current Coastal Province
# 3       longhurst.3     TASM               Westerlies - Tasman Sea Province
# 4       longhurst.4     BRAZ      Coastal - Brazil Current Coastal Province
# 5       longhurst.5     SATL  Trades - South Atlantic Gyral Province (SATG)
#
#         lon_min  lon_max lat_min lat_max    provType  provCat
# provNo
# 1         -70.5    -51.5   -55.5   -38.5     Coastal        0
# 2         -86.5    -69.5   -55.5     0.5     Coastal        0
# 3         146.5  174.975   -43.5   -33.5  Westerlies        3
# 4      -58.5497    -33.5   -41.5   -10.5     Coastal        0
# 5         -53.5     15.5   -41.5    -2.5      Trades        2

# %%
d = d[['provID', 'provCode', 'provType', 'provCat', 'provName', 'lon_min', 'lon_max', 'lat_min', 'lat_max']]

# %%
d.head()
# Out:
#               provID provCode    provType  provCat  \
# provNum
# 1        longhurst.1     FKLD     Coastal        0
# 2        longhurst.2     CHIL     Coastal        0
# 3        longhurst.3     TASM  Westerlies        3
# 4        longhurst.4     BRAZ     Coastal        0
# 5        longhurst.5     SATL      Trades        2
#
#                                               provName  lon_min  lon_max  \
# provNum
# 1               Coastal - SW Atlantic Shelves Province    -70.5    -51.5
# 2        Coastal - Chile-Peru Current Coastal Province    -86.5    -69.5
# 3                     Westerlies - Tasman Sea Province    146.5  174.975
# 4            Coastal - Brazil Current Coastal Province -58.5497    -33.5
# 5        Trades - South Atlantic Gyral Province (SATG)    -53.5     15.5
#
#         lat_min lat_max
# provNum
# 1         -55.5   -38.5
# 2         -55.5     0.5
# 3         -43.5   -33.5
# 4         -41.5   -10.5
# 5         -41.5    -2.5

# %%
d.lon_min = d.lon_min.astype('float')
d.lon_max = d.lon_max.astype('float')
d.lat_min = d.lat_min.astype('float')
d.lat_max = d.lat_max.astype('float')

# %%
d.head()
# Out:
#               provID provCode    provType  provCat  \
# provNum
# 1        longhurst.1     FKLD     Coastal        0
# 2        longhurst.2     CHIL     Coastal        0
# 3        longhurst.3     TASM  Westerlies        3
# 4        longhurst.4     BRAZ     Coastal        0
# 5        longhurst.5     SATL      Trades        2
#
#                                               provName     lon_min  \
# provNum
# 1               Coastal - SW Atlantic Shelves Province  -70.500000
# 2        Coastal - Chile-Peru Current Coastal Province  -86.500000
# 3                     Westerlies - Tasman Sea Province  146.500000
# 4            Coastal - Brazil Current Coastal Province  -58.549728
# 5        Trades - South Atlantic Gyral Province (SATG)  -53.500000
#
#             lon_max  lat_min  lat_max
# provNum
# 1        -51.500000    -55.5    -38.5
# 2        -69.500000    -55.5      0.5
# 3        174.974973    -43.5    -33.5
# 4        -33.500000    -41.5    -10.5
# 5         15.500000    -41.5     -2.5

# %%
d.provType.value_counts()
# Out:
# Coastal       22
# Westerlies    14
# Trades        12
# Polar          6
# Name: provType, dtype: int64

# %%
d.provCat.value_counts()
# Out:
# 0    22
# 3    14
# 2    12
# 1     6
# Name: provCat, dtype: int64

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54 entries, 1 to 54
# Data columns (total 9 columns):
# provID      54 non-null object
# provCode    54 non-null object
# provType    54 non-null object
# provCat     54 non-null int8
# provName    54 non-null object
# lon_min     54 non-null float64
# lon_max     54 non-null float64
# lat_min     54 non-null float64
# lat_max     54 non-null float64
# dtypes: float64(4), int8(1), object(4)
# memory usage: 6.3+ KB

# %%
d.to_pickle('../Bayesian-Chlorophyll/pickleJar/d_longhurst.pkl')

# %%
import pickle
from bokeh.palettes import mpl, d3, brewer
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, HoverTool, Panel
from bokeh.models.widgets import CheckboxGroup, Tabs
from bokeh.layouts import WidgetBox, row
from bokeh.io import output_notebook, curdoc
from bokeh.application.handlers import FunctionHandler
from bokeh.application import Application
import pandas as pd

# %%
curdoc()

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5aead2a2-6b54-4862-8d96-4d733dd14d8d">Loading BokehJS ...</span>
#     </div>

# %%
z= 'abcde'

# %%
list(z)
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
data = {'x_vals': [1, 2, 3, 4, 5],
       'y_vals': [6, 7, 2 ,3, 6],
       'name': list('abcde')}

# %%
source = ColumnDataSource(data=data)
tools = ['hover','reset']
p = figure()
p.circle(x='x_vals', y='y_vals', source=source);
show(p)

# %%
biome_pal = brewer['Pastel1'][df.biome.unique().size]

# %%
mxbl_pal = brewer['GnBu'][7][:df.mxblID.unique().size]

# %%
df = pd.read_pickle('./pickleJar/df_log.pkl')

# %%
df.insert(df.columns.get_loc('mxblID')+1, 'mxBlCat',
          df.mxblID.astype('category').cat.codes)

# %%
df.loc[df.mxblID=='rrs443_l', ['mxblID', 'mxBlCat']].iloc[0,:]
# Out:
# mxblID     rrs443_l
# mxBlCat           0
# Name: 14, dtype: object

# %%
df.head().T
# Out:
#                                 0                    1                    2  \
# id                           1565                 1566                 1567
# datetime      2003-04-15 15:15:00  2003-04-15 16:50:00  2003-04-15 17:50:00
# lat                       38.4279               38.368              38.3074
# lon                        -76.61                -76.5               -76.44
# etopo2_l                       -6                   -6          4.34294e-07
# oisst_l                  0.568202             0.568202             0.568202
# sal_l                         NaN                  NaN                  NaN
# rrs411_l                 -2.91923               -2.974             -3.01272
# rrs443_l                 -2.77312             -2.85886              -2.9261
# rrs489_l                  -2.4824             -2.66296             -2.73443
# rrs510_l                 -2.39401             -2.60219              -2.6406
# rrs555_l                 -2.12615             -2.38173             -2.37206
# rrs670_l                 -2.46035             -2.77086             -2.79256
# provCode                     NWCS                 NWCS                 NWCS
# provCat                        17                   17                   17
# biome                     Coastal              Coastal              Coastal
# biomCat                         0                    0                    0
# mxbl-gr                 -0.267867            -0.220457            -0.268537
# r411_2_r555               1.37301              1.24867              1.27009
# mxbl2gr                   1.12599              1.09256              1.11321
# mxblID                   rrs510_l             rrs510_l             rrs510_l
# mxBlCat                         2                    2                    2
# r411_toRed                1.18651              1.07331              1.07884
# chl_l                     1.58195              1.54419              1.42991
# blueBiome        rrs510_l-Coastal     rrs510_l-Coastal     rrs510_l-Coastal
# blueProvince        rrs510_l-NWCS        rrs510_l-NWCS        rrs510_l-NWCS
#
#                                 3                    4
# id                           1568                 1559
# datetime      2003-04-17 18:15:00  2003-07-21 18:27:00
# lat                       38.6367              38.3047
# lon                        -76.32               -76.44
# etopo2_l                 0.477121          4.34294e-07
# oisst_l                  0.568202              1.34301
# sal_l                         NaN                  NaN
# rrs411_l                 -2.83215             -3.04331
# rrs443_l                 -2.75914             -2.99041
# rrs489_l                 -2.54101              -2.8222
# rrs510_l                 -2.43601             -2.72047
# rrs555_l                 -2.15604             -2.55274
# rrs670_l                 -2.49028             -2.74702
# provCode                     NWCS                 NWCS
# provCat                        17                   17
# biome                     Coastal              Coastal
# biomCat                         0                    0
# mxbl-gr                 -0.279976            -0.167733
# r411_2_r555               1.31359              1.19218
# mxbl2gr                   1.12986              1.06571
# mxblID                   rrs510_l             rrs510_l
# mxBlCat                         2                    2
# r411_toRed                1.13728              1.10786
# chl_l                     1.68088              1.37199
# blueBiome        rrs510_l-Coastal     rrs510_l-Coastal
# blueProvince        rrs510_l-NWCS        rrs510_l-NWCS

# %%
df.insert(df.columns.get_loc('biomCat')+1, 'biomColor',
          df.biomCat.apply(lambda x: biome_pal[x]))

# %%
df.insert(df.columns.get_loc('mxBlCat')+1, 'mxBlColor',
          df.mxBlCat.apply(lambda x: mxbl_pal[x]))

# %%
df['mxblID'] = df.mxblID.str.strip('_l')

# %%
df.tail().T
# Out:
#                              4454                 4455                 4456  \
# id                           6901                 6902                 6914
# datetime      2006-10-05 15:40:00  2006-10-05 17:00:00  2006-10-05 18:10:00
# lat                       26.3795              26.3167              26.2545
# lon                      -82.2707             -82.4491             -82.6158
# etopo2_l                  1.41497              1.34242              1.38021
# oisst_l                   1.46105              1.46105              1.46105
# sal_l                     1.55159              1.55133              1.55133
# rrs411_l                 -2.95869             -2.74476             -2.56859
# rrs443_l                 -2.85387              -2.7213             -2.52291
# rrs489_l                 -2.65753             -2.63822             -2.43176
# rrs510_l                 -2.61974              -2.6383              -2.4815
# rrs555_l                 -2.50859             -2.58507             -2.58508
# rrs670_l                   -3.155             -3.30095             -3.39809
# provCode                     SARC                 SARC                 SARC
# provCat                        47                   47                   47
# biome                  Westerlies           Westerlies           Westerlies
# biomCat                         3                    3                    3
# biomColor                 #decbe4              #decbe4              #decbe4
# mxbl-gr                  -0.11115           -0.0531435             0.153314
# r411_2_r555               1.17942              1.06177             0.993623
# mxbl2gr                   1.04431              1.02056             0.940693
# mxblID                     rrs510               rrs489               rrs489
# mxBlCat                         2                    1                    1
# mxBlColor                 #2b8cbe              #0868ac              #0868ac
# r411_toRed               0.937778             0.831507             0.755892
# chl_l                    0.665378             0.471287           -0.0217556
# blueBiome     rrs510_l-Westerlies  rrs489_l-Westerlies  rrs489_l-Westerlies
# blueProvince        rrs510_l-SARC        rrs489_l-SARC        rrs489_l-SARC
#
#                              4457                 4458
# id                           6903                 6915
# datetime      2006-10-05 20:30:00  2006-10-05 21:22:00
# lat                       26.5184              26.5567
# lon                      -82.5594             -82.4766
# etopo2_l                  1.38021              1.25527
# oisst_l                   1.46105              1.46105
# sal_l                     1.55095              1.55093
# rrs411_l                 -3.15448              -3.1549
# rrs443_l                 -3.09666             -3.04545
# rrs489_l                 -2.95856             -2.85383
# rrs510_l                 -2.92101             -2.79609
# rrs555_l                 -2.82393             -2.61985
# rrs670_l                  -3.3015             -3.15517
# provCode                     PSAE                 PSAE
# provCat                        47                   47
# biome                  Westerlies           Westerlies
# biomCat                         3                    3
# biomColor                 #decbe4              #decbe4
# mxbl-gr                -0.0970788            -0.176237
# r411_2_r555               1.11705              1.20423
# mxbl2gr                   1.03438              1.06727
# mxblID                     rrs510               rrs510
# mxBlCat                         2                    2
# mxBlColor                 #2b8cbe              #2b8cbe
# r411_toRed               0.955469             0.999915
# chl_l                    0.657274             0.763947
# blueBiome     rrs510_l-Westerlies  rrs510_l-Westerlies
# blueProvince        rrs510_l-PSAE        rrs510_l-PSAE

# %%
dfs = df[['mxbl-gr', 'mxbl2gr', 'r411_2_r555', 'r411_toRed', 
          'mxblID', 'mxBlColor', 'provCode', 'biome', 'biomColor','chl_l']]

# %%
color_dict
# Out:
# {'biome': 'biomColor'}

# %%
def modify_category_plot(doc):
    def make_new_source(cat_list):
        filtered_df = dfs[dfs[selection_label].isin(cat_list)]
        return ColumnDataSource(filtered_df)

    def make_checkboxgroup():
        categories = dfs[selection_label].unique().tolist()
        cbg_selection = CheckboxGroup(labels=categories,
                                     active=list(range(len(categories))))
        return cbg_selection

    def update(attr, old, new):
        # get the list of selections to graph
        selections_to_plot = [selection.labels[i] for i in selection.active]

        # make a new dataset based on the selection and the make_dataset function
        new_source = make_new_source(selections_to_plot)
        # Update the source used in the plot
        source.data.update(new_source.data)
        
    def make_plot(src):
        biome_selection = CheckboxGroup(labels=df.biome.unique().tolist(), )
        p = figure(plot_width=600, plot_height=600,
                   title=plot_title, x_axis_label=x_lbl,
                   y_axis_label='log(chl)')
        p.circle(x=x_data_col_name, y='chl_l', fill_color=color_dict[selection_label],
                 size=10, line_color='black',source=src,)
        hover = HoverTool(tooltips=cur_tool_tip)
        p.add_tools(hover)
        return p
    
    selection = make_checkboxgroup()
    selection.on_change('active', update)
    initial_selection = [selection.labels[i] for i in selection.active]
    source = make_new_source(initial_selection)
    p = make_plot(source)
    control=WidgetBox(selection, width=120)
    layout = row(control, p)
    doc.add_root(layout)

# %%
plot_title = 'OC4'
x_lbl = 'log(max(Blue)) - log(Green)'
x_data_col_name = 'mxbl-gr'
cur_tool_tip = [#('biome', '@biome'),
                ('maxBlue', '@mxblID'),('province', '@provCode')]
selection_label = 'biome'
color_dict = dict(biome='biomColor', )
source = ColumnDataSource(dfs)
handler = FunctionHandler(modify_category_plot)
app = Application(handler)
show(app)
# Out:
# <script
#     src="http://localhost:45166/autoload.js?bokeh-autoload-element=498914db-c6bd-4b43-a604-f72a0f65b994&bokeh-absolute-url=http://localhost:45166&resources=none"
#     id="498914db-c6bd-4b43-a604-f72a0f65b994"
#     data-bokeh-model-id=""
#     data-bokeh-doc-id=""
# ></script>

# %%
plot_title = 'OC4'
x_lbl = 'log(max(Blue)) - log(Green)'
x_data_col_name = 'mxbl-gr'
cur_tool_tip = [('biome', '@biome'),
                #('maxBlue', '@mxblID'),
                ('province', '@provCode')]
selection_label = 'mxblID'
color_dict = dict(mxblID='mxBlColor', )
source = ColumnDataSource(dfs)
handlerb2g = FunctionHandler(modify_category_plot)
appb2g = Application(handlerb2g)
show(appb2g)
# Out:
# <script
#     src="http://localhost:36496/autoload.js?bokeh-autoload-element=988ada7d-c8dc-4894-8959-c52584999e68&bokeh-absolute-url=http://localhost:36496&resources=none"
#     id="988ada7d-c8dc-4894-8959-c52584999e68"
#     data-bokeh-model-id=""
#     data-bokeh-doc-id=""
# ></script>
